# %%
from selenium import webdriver

# %% [markdown]
# Mad Money is an American finance television program hosted by Jim Cramer that began airing on CNBC on March 14, 2005. Its main focus is investment and speculation, particularly in public company stocks. Mad Money. Genre. Talk show.

# %%
#### import all required libraries and run selenium in headless mode, and will extract data of mad money you tube videos

# %%
from selenium.webdriver.chrome.options import Options

# %%
from selenium.webdriver.chrome.service import Service

# %%
#### youtube url for mad money playlist

# %%
website = "https://www.youtube.com/playlist?list=PLVbP054jv0KpV2leJ9HHIMqZEkCPX-iPV"

# %%
#### path for driver location

# %%
path = "/Users/sharukh-malik/Downloads/chrome_driver/"

# %%
# headless mode

# %%
options = Options()

# %%
options.headless = True
# Out:
# /var/folders/gp/q35fhh7x7ld625zg0w3z4tkm0000gn/T/ipykernel_34216/118017539.py:1: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True

# %%
service = Service(excecutable_path = path)

# %%
driver  = webdriver.Chrome(service = service, options=options)

# %%
driver.get(website)

# %%
#### xpath taken from inspect page of madmoney ypu tube page

# %%
containers = driver.find_elements(by = "xpath", value='//div[@id="content"]//div[@id="contents"]//div[@id="content"]//div[@id="meta"]')

# %%
titles = []
views = []
channel = []
links = []

# %%
import pandas as pd

# %%
### based on available I have target three features title, views, channel, links

# %%
for container in containers:
    title = container.find_element(by = "xpath", value='./h3/a').get_attribute("title")
    tag = container.find_element(by = "xpath", value='.//a[@class="yt-simple-endpoint style-scope yt-formatted-string"]').text
    view = container.find_element(by = "xpath", value='.//span[1][contains(@class, "style-scope yt-formatted-string")]').text
    
    link = container.find_element(by = "xpath", value='.//a[@class="yt-simple-endpoint style-scope yt-formatted-string"]').get_attribute("href")
    

# 
    titles.append(title)
    views.append(view.split(" ")[0])
    channel.append(tag.split(" ")[0])
    links.append(link)

# %%
titles
# Out:
# ['Electric vehicles could be losing their excitment factor, says Jim Cramer',
#  'Microsoft off to a good start, has a long way to go with secure service edge: Palo Alto Network CEO',
#  'Lightning Round: I was positive on RH while the CEO was negative, says Jim Cramer',
#  'Apple is crushing it because it has the best subscription product in the world, says Jim Cramer',
#  'Anything that has to do with travel and leisure is a winner this earnings season, says Jim Cramer',
#  'We forget the U.S. is a services based country, not a manufacturing country, says Jim Cramer',
#  "Jim Cramer goes behind the scenes to show how the portfolio 'sausage' gets made",
#  'Lightning Round: The only way Paramount can be saved is if it gets taken over, says Jim Cramer',
#  "'Going in the right direction' won't stop the Fed on rate hikes, says Jim Cramer",
#  "Jim Cramer has his eyes on the 'Magnificent Seven'",
#  'Being short on a stock is much more difficult than being long, says Jim Cramer',
#  'Lightning Round: Hard pass on Quantumscape, says Jim Cramer',
#  'The game of short selling is one-sided and unfair, says Jim Cramer',
#  'China needs a better relationship with us than we do with them, says Jim Cramer',
#  'We strongly support enforcement of the law, says Fmr. CFTC Chair on crypto regulation',
#  'Lightning Round: Icahn Enterprises probably has another 10% higher to go, says Jim Cramer',
#  "You're better off investing in a Chinese company that can accelerate growth in the U.S.: Jim Cramer",
#  'Our China business is back, says Levi Strauss CEO Chip Bergh',
#  'We are going to see a smoking hot jobs number Friday, says Jim Cramer',
#  'Lightning Round: Ferrari is a true juggernaut, says Jim Cramer',
#  "It might be 'idiocy' to buy ahead of earnings season, says Jim Cramer",
#  'Lightning Round: Let Carnival Cruise Line simmer and go to Norwegian Cruise Line, says Jim Cramer',
#  "Go with what's working instead of waiting for what is not working, says Jim Cramer",
#  'On Co-CEO Martin Hoffmann sits down with Jim Cramer',
#  'Retail stores elevate how you experience the brand, says On Co-CEO Martin Hoffmann',
#  "How could the market broaden out when so many companies have become 'have nots', says Jim Cramer",
#  'Good performance can be directly linked to having fewer positions, says Jim Cramer',
#  'Keep your eye on bonds, says Jim Cramer',
#  "'Sooner or later we will have a pullback' so be ready, says Jim Cramer",
#  "There will almost always be a better time to sell outside of a 'panic' moment, says Jim Cramer",
#  "'Never buy all at once', says Jim Cramer on his guide to investing",
#  "You need to do your homework if you're going to own stocks, says Jim Cramer",
#  'Never subsidize losers with winners, says Jim Cramer',
#  'You absolutely need to explain your stock picks to another humanbeing, says Jim Cramer',
#  'Patience is a virtue when investing, says Jim Cramer',
#  "Jim Cramer talks how to spot 'best of breed stocks' when investing",
#  "Don't take the money and run, go back in and reinvest, says Jim Cramer",
#  'Jim Cramer reveals rules for investing he lives by',
#  'If you push your luck by staying short too long you get sent to the slaughter house, says Jim Cramer',
#  "Pay close attention to 'future bookings' during the Carnival earnings call, says Jim Cramer",
#  "I like aerospace right now because of airlines' high demand for planes, says Jim Cramer",
#  "Lightning Round: It's never too late to sell ADT 'it has been an abomination', says Jim Cramer",
#  "'I sure wouldn't fight anyone who wants a piece of Micron, says Jim Cramer",
#  "We're in a stock market 'no man's land', says Jim Cramer",
#  "Lightning Round: AMD is 'okay' just not as 'fabulous' as the market thought it was, says Jim Cramer",
#  "When it comes to the stock market 'I recommend sitting on your hands right now', says Jim Cramer",
#  'Lightning Round: Icahn Enterprises is too dangerous for me, says Jim Cramer',
#  'Ford CEO Jim Farley: EV adoption comes down to charging infrastructure',
#  'I think there is real value in Ford, says Jim Cramer',
#  "'I don't think Ford and Tesla are mutually exclusive', says Jim Cramer",
#  "Jim Cramer takes a bite out of Domino's stock",
#  'What we need from the Fed is narrow transparency, says Jim Cramer',
#  "The next stock market sell-off will be a 'bullish decline', says Jim Cramer",
#  'Lightning Round: Dominion Energy is a little to risky for me, says Jim Cramer',
#  'I would use any upcoming sell-off as a chance to get into the stock market, say Jim Cramer',
#  'CAVA buyers are drawn in by FOMO, says Jim Cramer',
#  "Adobe CEO Shantanu Narayen says A.I. is 'going to make people so much more productive'",
#  'Lightning Round: Microsoft has been very smart with its A.I. implementation, says Jim Cramer',
#  "The only group that bull market buyers aren't buying right now is tech, says Jim Cramer",
#  "AMD's new chips are bad news for China, says Jim Cramer",
#  "It's going to be very hard for China to regain its preeminence in manufacturing, says Jim Cramer",
#  'Lightning Round: Healthcare is a screaming buy right now, says Jim Cramer',
#  "We're the 'central nervous system' for data streaming, says Confluent CEO Jay Kreps",
#  "I don't trust my fellow shareholders right now and you shouldn't either, says Jim Cramer",
#  'The Fed wants to kill inflation by killing wage growth, says Jim Cramer',
#  'Lightning Round: Too much competition in the Fintech space for PayPal, says Jim Cramer',
#  'Those coming into the market now are late to the party, says Jim Cramer',
#  'The market has been winning for months, but they were ugly wins, says Jim Cramer',
#  "'I expect Cava to roar' on IPO, says Jim Cramer",
#  "Idea that Apple Vision Pro's high price point will be use optimal is 'dead wrong', says Jim Cramer",
#  "Salesforce CEO Marc Benioff: the A.I. 'trust layer' will anaonamize data to add a level of security",
#  'There are tons of stock winners outside tech, says Jim Cramer',
#  "Lightning Round: Duke Energy is moving with the cohort but it's not a stock to be worried about",
#  "There's nothing narrow about current tech winners, says Jim Cramer on the stock market rally",
#  'Oshkosh CEO John Pfeifer says A.I. advancement will lead to better unmanned productivity',
#  'Cramer gives his read on the resilient job market',
#  'Cramer on why the A.I. bears may be wrong',
#  "Lightning Round: I've given up on Plug Power, too many disappointments and too many strikes",
#  'Cramer takes on the bull and bear debate over A.I.',
#  'Wheaton Precious Metals CEO Randy Smallwood: Our growth profile will add more happy shareholders',
#  "Campbell's still seeing growth from canned soup business, says CEO Mark Clouse",
#  'Royal Caribbean has already started showing signs of a real turnaround, says Jim Cramer',
#  'Lightning Round: I like mineral stocks that are well run like Rio Tinto, says Jim Cramer',
#  "Jim Cramer looks back on October's market bottom",
#  'Lightning Round: If you have to buy Chinese stock buy Alibaba, says Jim Cramer',
#  "Timothy Massad: crypto risk 'isn't just about the token' it's about the 'platform you're trading on'",
#  "I wish someone would tell people messing in crypto it's possible to lose everything, says Jim Cramer",
#  "Most crypto assets look like 'scams', says Jim Cramer",
#  "The debt ceiling deal spurred Friday's rally not the jobs report, says Jim Cramer",
#  'Traders should be prepared for a stock market pullback to begin, says Jim Cramer',
#  'Lightning Round: Sell Rivian and sell Lucid, says Jim Cramer',
#  "You'll have to take some pain to see gains in the stock market, says Jim Cramer",
#  'Labor report makes Fed pause more likely, says Jim Cramer',
#  'Lightning Round: I think SoundHound is a meme stock, says Jim Cramer',
#  '"I liked the market more yesterday than I do today", says Jim Cramer',
#  'Lightning Round: American Express is benefiting from people going out at night',
#  "It's not bad that top stock performers are strong, says Jim Cramer",
#  "'Adversarial A.I.' is A.I. made to take down security technology, says CrowdStrike CEO George Kurtz",
#  "Jim Cramer highlights the stock market's 'Magnificent Seven' outperforming stocks",
#  'Commodity prices are plummeting in sync with a recession, says Jim Cramer']

# %%
views
# Out:
# ['2.4K',
#  '4.5K',
#  '6.2K',
#  '9.4K',
#  '39K',
#  '4.9K',
#  '3.9K',
#  '6K',
#  '28K',
#  '17K',
#  '1.8K',
#  '2.4K',
#  '25K',
#  '1.7K',
#  '1.1K',
#  '3.9K',
#  '29K',
#  '2.8K',
#  '3K',
#  '5.1K',
#  '31K',
#  '9.4K',
#  '30K',
#  '5.2K',
#  '679',
#  '2.6K',
#  '4.3K',
#  '6.5K',
#  '14K',
#  '2.6K',
#  '7.6K',
#  '1.6K',
#  '3.3K',
#  '4.9K',
#  '2.7K',
#  '26K',
#  '6.3K',
#  '23K',
#  '5.9K',
#  '4.3K',
#  '5K',
#  '5.8K',
#  '26K',
#  '3.9K',
#  '9K',
#  '44K',
#  '2.6K',
#  '7.5K',
#  '23K',
#  '6.1K',
#  '4.8K',
#  '1.1K',
#  '8.3K',
#  '4.4K',
#  '67K',
#  '4.3K',
#  '6.5K',
#  '6.1K',
#  '59K',
#  '6.7K',
#  '11K',
#  '7.2K',
#  '5.7K',
#  '54K',
#  '3.3K',
#  '5.7K',
#  '42K',
#  '2.4K',
#  '3.6K',
#  '4.7K',
#  '4.5K',
#  '2.4K',
#  '2.8K',
#  '27K',
#  '2.9K',
#  '13K',
#  '4K',
#  '8.8K',
#  '28K',
#  '705',
#  '1.6K',
#  '3.9K',
#  '3K',
#  '29K',
#  '8.1K',
#  '3.2K',
#  '3.3K',
#  '29K',
#  '3K',
#  '32K',
#  '16K',
#  '47K',
#  '13K',
#  '7.3K',
#  '59K',
#  '3.8K',
#  '3.5K',
#  '1.4K',
#  '28K',
#  '6.4K']

# %%
channel
# Out:
# ['CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC',
#  'CNBC']

# %%
links
# Out:
# ['https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision',
#  'https://www.youtube.com/@CNBCtelevision']

# %%
my_dict = {"titles":titles, "channel": channel, "total_views": views, "video_link":links}

# %%
df = pd.DataFrame(my_dict)

# %%
df
# Out:
#                                                titles channel total_views  \
# 0   Electric vehicles could be losing their excitm...    CNBC        2.4K
# 1   Microsoft off to a good start, has a long way ...    CNBC        4.5K
# 2   Lightning Round: I was positive on RH while th...    CNBC        6.2K
# 3   Apple is crushing it because it has the best s...    CNBC        9.4K
# 4   Anything that has to do with travel and leisur...    CNBC         39K
# ..                                                ...     ...         ...
# 95  Lightning Round: American Express is benefitin...    CNBC        3.8K
# 96  It's not bad that top stock performers are str...    CNBC        3.5K
# 97  'Adversarial A.I.' is A.I. made to take down s...    CNBC        1.4K
# 98  Jim Cramer highlights the stock market's 'Magn...    CNBC         28K
# 99  Commodity prices are plummeting in sync with a...    CNBC        6.4K
#
#                                  video_link
# 0   https://www.youtube.com/@CNBCtelevision
# 1   https://www.youtube.com/@CNBCtelevision
# 2   https://www.youtube.com/@CNBCtelevision
# 3   https://www.youtube.com/@CNBCtelevision
# 4   https://www.youtube.com/@CNBCtelevision
# ..                                      ...
# 95  https://www.youtube.com/@CNBCtelevision
# 96  https://www.youtube.com/@CNBCtelevision
# 97  https://www.youtube.com/@CNBCtelevision
# 98  https://www.youtube.com/@CNBCtelevision
# 99  https://www.youtube.com/@CNBCtelevision
#
# [100 rows x 4 columns]

# %%
file_name = "news.csv"

# %%
df.to_csv(file_name)

# %%
driver.quit()
